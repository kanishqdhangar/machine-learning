# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishqdhangar/machine-learning/blob/main/pandas/pandas-2-fortune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
company=pd.read_csv('/content/Fortune 500 Companies US.csv', encoding='latin-1')

# %%
company.head(2)
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035

# %%
type(company.groupby('Number of Employees'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
sector=company.groupby('Number of Employees')

# %%
sector.groups
# Out:
# {'1,00,300': [63], '1,03,500': [138], '1,05,000': [35], '1,06,000': [46, 220], '1,08,000': [129], '1,10,000': [197, 499], '1,14,000': [27, 81], '1,16,000': [2], '1,16,050': [135], '1,16,475': [133], '1,21,000': [127], '1,22,300': [66], '1,25,000': [71], '1,26,400': [34], '1,31,000': [72], '1,326': [479], '1,33,600': [161], '1,35,000': [177], '1,36,000': [80], '1,38,000': [40, 151], '1,40,000': [126], '1,464': [188], '1,48,300': [109], '1,48,400': [150], '1,50,540': [23], '1,50,942': [384], '1,59,000': [30], '1,60,900': [13], '1,69,000': [240], '1,72,000': [15], '1,770': [333], '1,91,000': [84], '1,95,000': [51, 58], '1,970': [401], '10,000': [208, 271], '10,212': [125], '10,299': [386], '10,400': [340], '10,471': [314], '10,700': [477], '10,900': [459], '11,000': [277, 455, 464], '11,121': [214], '11,170': [317], '11,300': [336], '11,320': [64], '11,476': [255], '11,500': [329, 349], '11,737': [76], '11,781': [485], '11,800': [447], '11,870': [484], '11,900': [266, 468], '12,030': [4
# ...

# %%
sector.sum()
# Out:
#                      Rank              Company Name  Previous Rank  \
# Number of Employees
# 1,00,300               64                 Coca-Cola           62.0
# 1,03,500              139          Emerson Electric          128.0
# 1,05,000               36          Procter & Gamble           34.0
# 1,06,000              268          IntelJ.C. Penney          279.0
# 1,08,000              130  Community Health Systems          125.0
# ...                   ...                       ...            ...
# 93,000                137                 Whirlpool          134.0
# 95,400                 74               Caterpillar           59.0
# 96,500                 54                    Pfizer           55.0
# 97,000                 56           Lockheed Martin           60.0
# 98,800                 90          General Dynamics           88.0
#
#                            Revenues Revenue Change        Profits  \
# Number of Employees
# ...
